# %% [markdown]
# <a href="https://colab.research.google.com/github/dickjuma/assignment-data-science/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import linear_model
juma= pd.read_csv('/content/juma.csv')
# %matplotlib inline
plt.title("ROAD ACCIDENTS RELATED TO ROAD CONDITIONS AND DRIVER STATUS")
plt.scatter(juma.number_of_accidents,juma.reckless_drivers)
plt.ylabel("Total accidents")
plt.xlabel("Number of accidennts caused by reckless driving")
plt.scatter(juma.number_of_accidents,juma.reckless_drivers)
plt.ylabel("Total accidents")
plt.xlabel("NON TARMAC ROADS NUMBERS OF ACCIDENTS")
plt.scatter(juma.number_of_accidents,juma.non_tarmac)

print(juma)
# Out:
#         MONTH  number_of_accidents  reckless_drivers  driver_on_influence  \
# 0     january                   66                45                   15
# 1    fabruary                   67                45                   17
# 2       march                   43                23                   18
# 3       april                   49                23                   23
# 4         may                  143                21                   77
# 5        june                   85                67                    9
# 6        july                  135                90                   23
# 7      august                   60                45                    7
# 8   september                   46                12                   12
# 9     october                  145               112                   31
# 10   november                  151                77                   29
# 11   december                   41                25                    4
#
# ...

# %%
RegrassionObject=linear_model.LinearRegression()
RegrassionObject.fit(juma[["juma.reckless_drivers"]],juma.value)
LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-67d2c56d7dbc> in <cell line: 2>()
#       1 RegrassionObject=linear_model.LinearRegression()
# ----> 2 RegrassionObject.fit(juma[["juma.reckless_drivers"]],juma.value)
#       3 LinearRegression()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
# ...
